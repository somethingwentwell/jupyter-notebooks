# %%
import os

os.environ["OPENAI_API_TYPE"] = "azure"
os.environ["AZURE_OPENAI_ENDPOINT"] = ""
os.environ["OPENAI_API_KEY"] = ""

# Import Azure OpenAI
from langchain_openai import AzureChatOpenAI
llm = AzureChatOpenAI(
    azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    openai_api_version="2023-12-01-preview",
    deployment_name="gpt-35-turbo-16k",
    model_name="gpt-35-turbo-16k",
    model_version="0613",
)

# %%
qnas = ["""
Competence requirements for individuals
For the purposes of these FAQs, where references to “corporation” are made, the term covers “registered institution”; similarly, where references to “responsible officer” are made, the term covers “executive officer” of a registered institution, references to the term “licensed representative” covers “relevant individual” of a registered institution.
(Q1 to Q5, Q7, Q9, Q11 and Q13 were either obsolete or elaborated in the Guidelines on Competence1 and removed on 26 January 2022)
(Q6, Q8, Q10 and Q12 were updated on 26 January 2022)
(Q14 to Q16 were added on 26 January 2022)
   (Q17 was added on 21 March 2023)
Collapse all >
Q1 : FAQ removed on 26 January 2022
A:
Q2 : FAQ removed on 26 January 2022
A:
Q3 : FAQ removed on 26 January 2022
A:
Q4 : FAQ removed on 26 January 2022
A:
We use cookies to improve the website performance and user experience. If you continue to use this website, you are agreeing to their uses. Learn more about our privacy policy.
 
 Q5 : FAQ removed on 26 January 2022
 A:
 Q6 : Regarding the exemption criteria as set out in paragraph 4.4.3.2 of the Guidelines on Competence, to what extent will an applicant’s activities be considered as “limited scope”?
 A: Examples of applicants’ involvement in “limited scope of activities” include:
1. Regional Research Head coming to Hong Kong occasionally and is accompanied by other local licensed staff in client meetings, or
2. persons only providing technical advice to clients on the structuring of corporate finance deals. The above examples are not intended to be exhaustive.
 Q7 : FAQ removed on 26 January 2022
 A:
 Q8 : Referring to the re-entrant exemption in paragraph 4.4.4 of the Guidelines on Competence, how many CPT2 hours does a former practitioner who had left the industry for four years and two months need to take before the former practitioner is eligible for this exemption?
 A: The requirement is five CPT hours per regulated activity for each year of absence. In this case, the former practitioner would have to complete 25 CPT hours for each applicable regulated activity (any fraction of a year would be rounded up for this purpose). The former practitioner should complete the required 25 CPT hours before lodging the application.
 Q9 : FAQ removed on 26 January 2022
 A:
  Q10 : What types of CPT would be relevant for the exemptions as set out in paragraph 4.4.2 and 4.4.3 of the Guidelines on Competence? When should the applicant complete the additional CPT hours and what are the consequences if the applicant fails to do so?
 3
We usAe:cooTkoiebsetoeilmigpibrolevefothrethwebRsIiQte pexrfeomrmpatinocnesanindpuaserargexrapperhie4n.c4e.2. IfoyfotuhceoGntuiniduelitnoeuseonthCisowmebpseitte,nycoeu,atrheeagreeing to
their uses. Learn more about our privacy policy.
additional CPT hours to be taken should be in industry or product knowledge in respect of the
 
 regulated activity applied for.
To be eligible for the LRP4 exemptions in paragraph 4.4.3 of the Guidelines on Competence, the additional CPT hours to be taken should be in local regulatory knowledge in respect of the regulated activity applied for.
The additional CPT hours may either be taken: (1) within 6 months preceding the application, or (2) within 12 months after the approval is granted. For (1), both the applicant and the sponsoring corporation should provide confirmation that the applicant has already completed the required CPT hours; for (2), both the applicant and the sponsoring corporation should provide undertakings to this effect.
If the applicant fails to complete the additional CPT hours as required, the fitness and properness of both the sponsoring corporation and the applicant may be impugned, and the applicant’s licensing status may be adversely affected.
 Q11 : FAQ removed on 26 January 2022
 A:
 Q12 : An applicant is currently licensed for Type 1 regulated activity. The applicant took HKSI5 LE6 Paper 1 before being licensed 4 years ago. Will the applicant be required to re-take Paper 1 before applying to additionally engage in Type 2 regulated activity?
 A: To apply for another type of regulated activity, the applicant should have passed the LRPs required for the new type of regulated activity.
Generally, applicants should pass the LRPs within three years preceding the application (see paragraph 4.1.5 of the Guidelines on Competence). However, the SFC may also recognise LRPs obtained more than three years ago if the applicant is a current licensee or has been licensed by the SFC within the past three years (see paragraph 4.1.6 of the Guidelines on Competence). In the above example, the applicant will not be required to re-take HKSI LE Paper 1 even if the exam was taken more than three years ago.
In the event that the applicant has never passed the LRPs required for the new type of regulated activity (e.g. the applicant was migrated to the Securities and Futures Ordinance regime by way of transitional arrangements and has never attempted HKSI LE Paper 1), the applicant will not be eligible for an LRP full exemption, but may apply for an appropriate conditional exemption (e.g. LRP Conditional Exemption 6 under paragraph 4.4.3.7 of the Guidelines on Competence) if the relevant eligibility criteria is satisfied.
 Q13 : FAQ removed on 26 January 2022
 A:
We use cookies to improve the website performance and user experience. If you continue to use this website, you are agreeing to their uses. Learn more about our privacy policy.
  
 Q14 : An applicant was last licensed on 30 June 2020 under Option 3 of the Guidelines on Competence (March 2003 version) and has left the industry since then. The applicant now rejoins the industry and applies for a new licence. Will the applicant be required to meet the academic qualification requirements under the Guidelines on Competence?
 A: No. Applicants who previously qualify under Option 3 and have been a licensee before 1 January 2022 may be grandfathered under paragraph 4.2.1.3 (for RO7) or 4.3.1.3 (for LR8) of the Guidelines on Competence, provided that they satisfy the other competence requirements stated therein, such as having recent and relevant industry experience, and meeting the RIQ and LRP requirements as applicable.
The grandfathering arrangement would also apply to situations where these applicants apply for addition of regulated activity or approval as RO.
 Q15 : Under paragraph 4.1.10 of the Guidelines on Competence, the SFC may consider an applicant’s overall career history within the industry in totality. Does this mean an applicant need not accumulate industry experience within the period prescribed in paragraph 4.2.1.2 (for RO) or 4.3.1.2 (for LR)?
 A: “Recency” is a key element to demonstrate that an applicant is on top of market developments and familiar with the regulatory landscape. While we may consider an applicant’s overall career history within the industry in totality on a case-by-case basis as mentioned in paragraphs 4.1.10 and 4.1.11 of the Guidelines on Competence, this approach mainly covers dated experience for applicants who cannot entirely satisfy the recency test.
For example, if an applicant will be assuming the role of the Manager-In-Charge of the Overall Management Oversight function and has not accumulated sufficient relevant industry experience entirely within the prescribed period, we will holistically take into account how the dated experience is relevant to the applicant’s proposed duties, and whether, for example, sufficient infrastructure and human resources are available to the applicant’s proposed accredited principal. If we accept the relevancy of the dated experience, the applicant may be granted a licence subject to licensing conditions.
  Q16 : What kind of “management experience” would the SFC consider as relevant for an RO application?
A: We consider that “management experience” should refer to the hands-on experience in supervising and managing essential regulated functions or projects in a business setting, including the management of staff engaging in these functions or projects.
This may include –
1. experience as senior management (e.g. Chief Executive, Business Head or Chief Operating Officer) of a licensed corporation, registered institution or a corporation within the financial industry supervising the performance of regulated activities or financial services;
2. experience in supervising an investment team in the performance of an investment function, whether regulated or not; or
 3. experience acquired from managing another type of regulated activity.
We use cookies to improve the website performance and user experience. If you continue to use this website, you are agreeing to
their uses. Learn more about our privacy policy.
 
The above examples are not intended to be exhaustive.
Q17 : Can an LR applicant who is experienced in the private fund management industry apply for LRP Conditional Exemption 4 under the Guidelines on Competence?
A: Yes. In line with the SFC’s risk-based and pragmatic licensing approach, we will consider granting conditional exemption to an LR applicant if he or she satisfies the criteria set out in paragraph 4.4.3.5 (a) to (c) of the Guidelines on Competence.
1 “Guidelines on Competence” means Guidelines on Competence (January 2022 version). 2 “CPT” means continuous professional training.
3 “RIQ” means recognised industry qualification.
4 “LRP” means local regulatory framework paper.
5 “HKSI” means Hong Kong Securities and Investment Institute.
6 “LE” means Licensing Examination for Securities and Futures Intermediaries. 7 “RO” means responsible officer.
8 “LR” means licensed representative.
Last update: 21 Mar 2023
""",
"""
Frequently Asked Questions
General
Print
Collapse
A1 What is personal data?
Personal data is recorded information, including expressions of opinion, relating to an identifiable living individual, which are organised such that they can be processed or retrieved. Examples of personal data used in everyday life include a person's name, telephone number, fax number, address, sex, age, occupation, marital status, salary and financial status, religious belief, nationality, photo, identity card number, medical records and employment records, including assessments of employment performance.
A2 Does personal data refer to personal data in written documents only?
No, apart from written documents, personal data in other forms, such as audio and video tapes, is also covered under the Ordinance.
A3 Does the Ordinance cover personal information held in both manual and computer files?
Yes, the Ordinance covers personal information in any type of storage system, subject to it meeting the definition of personal data.
A4 Are my rights relating to personal data protected in every sphere of life?
Basically yes, but there are certain exemptions from specific provisions of the Ordinance.. These have been provided for in order to maintain the convenience of everyday life and uphold certain social and public interests. One area of exemption relates to personal data held for domestic or recreational purposes. These are generally exempted from the requirements of the Ordinance.
To protect the public interest in such matters as security, defence, prevention or detection of crime, assessment or collection of tax, news activities and health, there are exemptions for data users from the requirements to grant access to individuals to their personal records and to limit the use of personal records to the original purpose at the time of the collection of information.
For employment-related records, there are certain limited exemptions from the requirement to comply with access requests from individuals. For example, some employment-related personal information held before came into effect is exempt from such access until 2002.
A5 Does the Ordinance cover private and public sector organisations, including Government departments?
 Yes, the Ordinance covers private sector and public sector, including Government departments. The Commissioner can carry out investigations in relation to data users in these sectors.
 Human Resource Management
 Print
 Expand
 A1 What is a "blind" recruitment advertisement in the context of the Code of Practice on Human Resource Management ("the Code")?
 A2 Under what circumstances can job applicants be asked in a recruitment advertisement to submit personal data?
 A3 Why is an employer required to identify itself in recruitment advertisements that solicit personal data from job applicants?
 A4 Some employers provide their fax number, postal address or e-mail address in a recruitment advertisement without explicitly asking job applicants to submit their personal data. Is this practice acceptable under the Code?
 Direct Marketing
 Print
 Expand
 A1 I have a savings account at "Bank A". Recently I received a phone call from a staff member of this bank marketing its investment products to me. I am really annoyed at this kind of direct marketing calls. How does the Ordinance protect me from the unsolicited approach?
 Disclosure of information
 Print
 Expand
 A1 I read from the news that a telephone company would provide its subscribers' telephone numbers and address information to the Fire Services Department ("FSD") to facilitate its handling of emergency calls more efficiently. Has it contravened the Ordinance?
 Employee Monitoring
A1 Can employers monitor employees' e-mails and phone calls?
A2 Can employers of domestic helpers install surveillance cameras at home?
A3 Can employers install pinhole cameras?
 Print
 Expand
   
 A4 What can employees do if they find employers not following the "Privacy Guidelines: Monitoring and Personal Data Privacy at Work"?
 Use of CCTV
Print
Expand
 A1 Can government departments install closed-circuit televisions at gambling and hawker blackspots in housing estates, such as pavilions and parks, to tackle the problems?
"""]

# %%
import time
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableParallel
from langchain_openai import ChatOpenAI

functions = [
    {
        "name": "faq_answer",
        "description": "A FAQ answer with reference",
        "parameters": {
            "type": "object",
            "properties": {
                "answer": {"type": "string", "description": "The answer of the user's question."},
                "reference": {
                    "type": "string",
                    "description": "The reference(s) of the answer. Answer N/A if not found.",
                },
            },
            "required": ["answer", "reference"],
        },
    }
]

faq_chains = []

for qna in qnas:
    faq_chain = ChatPromptTemplate.from_template("Find the answer of {question} from below faq:\n" + qna + "\nThe answer may not be show from this faq. Make sure you answer N/A if you are not confident to answer.") | llm.bind(function_call={"name": "faq_answer"}, functions=functions)
    faq_chains.append(faq_chain)

chain_dict = {f'ans{i}': chain for i, chain in enumerate(faq_chains)}  

map_chain = RunnableParallel(**chain_dict) 

question = "What is personal data?"  
result = map_chain.invoke({"question": question})  
print(result)
# Out:
# {'ans0': AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{\n  "answer": "Personal data refers to any information that relates to an identified or identifiable individual. It includes but is not limited to names, identification numbers, contact information, financial information, health information, and online identifiers.",\n  "reference": "N/A"\n}', 'name': 'faq_answer'}}), 'ans1': AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{\n  "answer": "Personal data is recorded information, including expressions of opinion, relating to an identifiable living individual, which are organised such that they can be processed or retrieved.",\n  "reference": "A1"\n}', 'name': 'faq_answer'}})}

# %%
import json

ans_list = []

for i in result:
    obj = json.loads(result[i].additional_kwargs["function_call"]["arguments"])
    if obj["reference"] != "N/A":
        ans_list.append(obj)

# %%
print(ans_list)
# Out:
# [{'answer': 'Personal data is recorded information, including expressions of opinion, relating to an identifiable living individual, which are organised such that they can be processed or retrieved.', 'reference': 'A1'}]
